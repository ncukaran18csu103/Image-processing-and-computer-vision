# %%
#EXPERIMENT 1
#Introduction to digital Image processing using PIL and cv2 libraries in python

# %%
# !pip install opencv-python 
# !pip install Pillow

# %%
import cv2
import PIL

# %%
#reading images
img = plt.imread('RGB.jpg')
print(img.shape,"\n")
print(img)
# Out:
# (360, 360, 3)
#
# [[[238 238 238]
#   [238 238 238]
#   [238 238 238]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  [[238 238 238]
#   [238 238 238]
#   [238 238 238]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  [[238 238 238]
#   [238 238 238]
#   [238 238 238]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  ...
#
#  [[238 238 238]
#   [238 238 238]
#   [238 238 238]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  [[238 238 238]
#   [238 238 238]
#   [238 238 238]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  [[238 238 238]
#   [238 238 238]
#   [238 238 238]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]]

# %%
print(np.shape(img))
print(type(img))
print(img.dtype)
# Out:
# (360, 360, 3)
# <class 'numpy.ndarray'>
# uint8

# %%
plt.imshow(img)
plt.show()

# %%
#splitting the images and making them and then adding them merging them
A_red = img[:, :, 0]
A_green = img[:, :, 1]
A_blue = img[:, :, 2]

plt.figure()
plt.imshow(A_red) #For a single channel / grayscale image you need to mention the colourmap
plt.title('The RED channel')

plt.figure()
plt.imshow(A_green)
plt.title('The GREEN channel')

plt.figure()
plt.imshow(A_blue)
plt.title('The BLUE channel')

plt.show()

# %%
# read image from pillow library
from PIL import Image #Python Imaging Library
A_gray = Image.open('macaw.jfif')
A_gray = A_gray.convert('L')

temp = np.asarray(A_gray.getdata(), dtype=np.float64).reshape((A_gray.size[1], A_gray.size[0]))
A_gr = np.asarray(temp, dtype=np.uint8)

# %%
plt.imshow(A_gr,cmap="gray")
